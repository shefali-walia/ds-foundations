# %%
# %load_ext sql
# %sql duckdb://
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %% [markdown]
# To create databse:
# ```sql
# CREATE DATABASE database_name;
# ```
#
# To create table:
# ```sql
# CREATE TABLE table_name (
#     column1 INT -- data type: integer
#     column2 VARCHAR(20) -- data type: characters of max length 20
# );
# ```
# Can also specify column as Primary Key - no duplicated allowed.
# write as: column1 INT PRIMARY KEY

# %%
# %%sql
# CREATE TABLE emp_list(
#     id INT PRIMARY KEY,
#     name VARCHAR(20)
# );
# Out:
# Running query in 'duckdb://'
# RuntimeError: (_duckdb.CatalogException) Catalog Error: Table with name "emp_list" already exists!
# [SQL: CREATE TABLE emp_list(
#     id INT PRIMARY KEY,
#     name VARCHAR(20)
# );]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %% [markdown]
# To retrieve a data from a table, we use `SELECT`. When using `SELECT`, you can also combine `FROM` to specify the table and `WHERE` to add any conditions.
# To select all columns, we use an asterisk (*).
# ```sql
# SELECT * FROM table_name;
# ```
#
# **Remember to add a semicolon at the end, which represents the end of a row.**

# %%
# %%sql
# SELECT * FROM emp_list;
# Out:
# Running query in 'duckdb://'
# +----+------+
# | id | name |
# +----+------+
# +----+------+

# %%
# %%sql
# INSERT INTO emp_list (id, name) VALUES (1, 'Yamada');
# Out:
# Running query in 'duckdb://'
# +-------+
# | Count |
# +-------+
# +-------+

# %%
# %%sql
# INSERT INTO emp_list (id, name) VALUES (2, 'Tanaka');
# Out:
# Running query in 'duckdb://'
# +-------+
# | Count |
# +-------+
# +-------+

# %%
# %%sql
# INSERT INTO emp_list (id, name) VALUES (3, 'Sato');
# Out:
# Running query in 'duckdb://'
# +-------+
# | Count |
# +-------+
# +-------+

# %%
# %%sql
# SELECT * FROM emp_list;
# Out:
# Running query in 'duckdb://'
# +----+--------+
# | id |  name  |
# +----+--------+
# | 1  | Yamada |
# | 2  | Tanaka |
# | 3  |  Sato  |
# +----+--------+

# %%
# %%sql
# SELECT name FROM sqlite_master WHERE type = 'table';
# Out:
# Running query in 'duckdb://'
# +----------+
# |   name   |
# +----------+
# | emp_list |
# +----------+

# %%
# %%sql
# CREATE TABLE emp_list2 (
#     id INT PRIMARY KEY,
#     name VARCHAR(20)
# );
# Out:
# Running query in 'duckdb://'
# +-------+
# | Count |
# +-------+
# +-------+

# %%
# %%sql
# INSERT INTO emp_list2 (id, name) VALUES (1, 'Tako');
# Out:
# Running query in 'duckdb://'
# +-------+
# | Count |
# +-------+
# +-------+

# %%
# %%sql
# INSERT INTO emp_list2 (id, name) VALUES (2, 'Daikisugi');
# Out:
# Running query in 'duckdb://'
# +-------+
# | Count |
# +-------+
# +-------+

# %%
# %%sql
# SELECT * FROM emp_list2;
# Out:
# Running query in 'duckdb://'
# +----+-----------+
# | id |    name   |
# +----+-----------+
# | 1  |    Tako   |
# | 2  | Daikisugi |
# +----+-----------+

# %% [markdown]
# We use `SELECT` statement with `WHERE` clause for conditional retrieval.
#
# ```sql
# SELECT column1, ... FROM table_name WHERE condition;
# ```
# By using `IN`, we can extract records that match several possible values.
# By using `LIKE`, we can perform partial (fuzzy) matching. One wildcard is `%`, which represents any number of characters, including zero.
#
# ```sql
# SELECT column1, ... FROM table_name
# WHERE columnN LIKE 'A%'; -- starts with A
# ```
#
# ```sql
# SELECT column1, ... FROM table_name
# WHERE columnN LIKE '%A%'; -- contains A
# ```
#
# ```sql
# SELECT column1, ... FROM table_name
# WHERE columnN LIKE '%A'; -- ends with A
# ```

# %%
# %%sql
# SELECT * FROM emp_list WHERE id=2;
# Out:
# Running query in 'duckdb://'
# +----+--------+
# | id |  name  |
# +----+--------+
# | 2  | Tanaka |
# +----+--------+

# %%
# %%sql
# SELECT * FROM emp_list WHERE id IN (1,2);
# Out:
# Running query in 'duckdb://'
# +----+--------+
# | id |  name  |
# +----+--------+
# | 1  | Yamada |
# | 2  | Tanaka |
# +----+--------+

# %%
# %%sql
# SELECT * FROM emp_list WHERE name LIKE 'S%';
# Out:
# Running query in 'duckdb://'
# +----+------+
# | id | name |
# +----+------+
# | 3  | Sato |
# +----+------+

# %% [markdown]
# ```sql
# UPDATE table_name
# SET column1 = value1, column2 = value2, ...
# WHERE condition;
# ```
#
# **Note that if you forget to add the conditions, all the records will be overwritten**.

# %%
# %%sql
# UPDATE emp_list
# SET name = 'Suzuki'
# WHERE id = 3;
# Out:
# Running query in 'duckdb://'
# +-------+
# | Count |
# +-------+
# +-------+

# %%
# %%sql
# SELECT * FROM emp_list;
# Out:
# Running query in 'duckdb://'
# +----+--------+
# | id |  name  |
# +----+--------+
# | 1  | Yamada |
# | 2  | Tanaka |
# | 3  | Suzuki |
# +----+--------+

# %%
# %%sql
# INSERT INTO emp_list (id, name) VALUES (4, 'Dummy');
# Out:
# Running query in 'duckdb://'
# +-------+
# | Count |
# +-------+
# +-------+

# %%
# %%sql
# SELECT * FROM emp_list;
# Out:
# Running query in 'duckdb://'
# +----+--------+
# | id |  name  |
# +----+--------+
# | 1  | Yamada |
# | 2  | Tanaka |
# | 3  | Suzuki |
# | 4  | Dummy  |
# +----+--------+

# %%
# %%sql
# DELETE FROM emp_list
# WHERE id = 4;
# Out:
# Running query in 'duckdb://'
# +-------+
# | Count |
# +-------+
# +-------+

# %%
# %%sql
# SELECT * FROM emp_list;
# Out:
# Running query in 'duckdb://'
# +----+--------+
# | id |  name  |
# +----+--------+
# | 1  | Yamada |
# | 2  | Tanaka |
# | 3  | Suzuki |
# +----+--------+

# %%
# %%sql
# ALTER TABLE emp_list ADD class INT;
# Out:
# Running query in 'duckdb://'
# +---------+
# | Success |
# +---------+
# +---------+

# %%
# %%sql
# ALTER TABLE emp_list ADD age INT;
# Out:
# Running query in 'duckdb://'
# +---------+
# | Success |
# +---------+
# +---------+

# %%
# %%sql
# SELECT * FROM emp_list;
# Out:
# Running query in 'duckdb://'
# +----+--------+-------+------+
# | id |  name  | class | age  |
# +----+--------+-------+------+
# | 1  | Yamada |  None | None |
# | 2  | Tanaka |  None | None |
# | 3  | Suzuki |  None | None |
# +----+--------+-------+------+

# %%
# %%sql
# UPDATE emp_list
# SET class = 1, age = 13
# WHERE id = 3;
# Out:
# Running query in 'duckdb://'
# +-------+
# | Count |
# +-------+
# +-------+

# %%
# %%sql
# SELECT * FROM emp_list;
# Out:
# Running query in 'duckdb://'
# +----+--------+-------+------+
# | id |  name  | class | age  |
# +----+--------+-------+------+
# | 1  | Yamada |  None | None |
# | 2  | Tanaka |  None | None |
# | 3  | Suzuki |   1   |  13  |
# +----+--------+-------+------+

# %%
# %%sql
# UPDATE emp_list
# SET class = 1, age = 14
# WHERE id = 1;
# Out:
# Running query in 'duckdb://'
# +-------+
# | Count |
# +-------+
# +-------+

# %%
# %%sql
# UPDATE emp_list SET class = 2, age = 13 WHERE id = 2;
# Out:
# Running query in 'duckdb://'
# +-------+
# | Count |
# +-------+
# +-------+

# %%
# %%sql
# SELECT * FROM emp_list;
# Out:
# Running query in 'duckdb://'
# +----+--------+-------+-----+
# | id |  name  | class | age |
# +----+--------+-------+-----+
# | 1  | Yamada |   1   |  14 |
# | 2  | Tanaka |   2   |  13 |
# | 3  | Suzuki |   1   |  13 |
# +----+--------+-------+-----+

# %%
# %%sql
# INSERT INTO emp_list (id, name, class, age)
# VALUES (4, 'Kato', 2, 15),(5,'Ito',3,12),(6,'Takeuchi',2,16),(7,'Kimura',3,11),(8,'Sato',1,14);
# Out:
# Running query in 'duckdb://'
# +-------+
# | Count |
# +-------+
# +-------+

# %%
# %%sql
# SELECT * FROM emp_list;
# Out:
# Running query in 'duckdb://'
# +----+----------+-------+-----+
# | id |   name   | class | age |
# +----+----------+-------+-----+
# | 1  |  Yamada  |   1   |  14 |
# | 2  |  Tanaka  |   2   |  13 |
# | 3  |  Suzuki  |   1   |  13 |
# | 4  |   Kato   |   2   |  15 |
# | 5  |   Ito    |   3   |  12 |
# | 6  | Takeuchi |   2   |  16 |
# | 7  |  Kimura  |   3   |  11 |
# | 8  |   Sato   |   1   |  14 |
# +----+----------+-------+-----+

# %%
# %%sql
# SELECT * FROM emp_list WHERE id = 4;
# Out:
# Running query in 'duckdb://'
# +----+------+-------+-----+
# | id | name | class | age |
# +----+------+-------+-----+
# | 4  | Kato |   2   |  15 |
# +----+------+-------+-----+

# %%
# %%sql
# UPDATE emp_list SET class = 7 WHERE id = 8;
# Out:
# Running query in 'duckdb://'
# +-------+
# | Count |
# +-------+
# +-------+

# %%
# %%sql
# SELECT * FROM emp_list WHERE id = 8;
# Out:
# Running query in 'duckdb://'
# +----+------+-------+-----+
# | id | name | class | age |
# +----+------+-------+-----+
# | 8  | Sato |   7   |  14 |
# +----+------+-------+-----+

# %%
# %%sql
# UPDATE emp_list SET class = 1 WHERE id = 8;
# Out:
# Running query in 'duckdb://'
# +-------+
# | Count |
# +-------+
# +-------+

# %%
# %%sql
# SELECT * FROM emp_list WHERE id = 8;
# Out:
# Running query in 'duckdb://'
# +----+------+-------+-----+
# | id | name | class | age |
# +----+------+-------+-----+
# | 8  | Sato |   1   |  14 |
# +----+------+-------+-----+

# %%
# %%sql
# ALTER TABLE emp_list ADD height INT;
# Out:
# Running query in 'duckdb://'
# +---------+
# | Success |
# +---------+
# +---------+

# %%
# %%sql
# SELECT * FROM emp_list;
# Out:
# Running query in 'duckdb://'
# +----+----------+-------+-----+--------+
# | id |   name   | class | age | height |
# +----+----------+-------+-----+--------+
# | 1  |  Yamada  |   1   |  14 |  None  |
# | 2  |  Tanaka  |   2   |  13 |  None  |
# | 3  |  Suzuki  |   1   |  13 |  None  |
# | 4  |   Kato   |   2   |  15 |  None  |
# | 5  |   Ito    |   3   |  12 |  None  |
# | 6  | Takeuchi |   2   |  16 |  None  |
# | 7  |  Kimura  |   3   |  11 |  None  |
# | 8  |   Sato   |   1   |  14 |  None  |
# +----+----------+-------+-----+--------+

# %%
# %%sql
# UPDATE emp_list
# SET height = 150 WHERE id <=4 ;
# Out:
# Running query in 'duckdb://'
# +-------+
# | Count |
# +-------+
# +-------+

# %%
# %%sql
# SELECT * FROM emp_list;
# Out:
# Running query in 'duckdb://'
# +----+----------+-------+-----+--------+
# | id |   name   | class | age | height |
# +----+----------+-------+-----+--------+
# | 1  |  Yamada  |   1   |  14 |  150   |
# | 2  |  Tanaka  |   2   |  13 |  150   |
# | 3  |  Suzuki  |   1   |  13 |  150   |
# | 4  |   Kato   |   2   |  15 |  150   |
# | 5  |   Ito    |   3   |  12 |  None  |
# | 6  | Takeuchi |   2   |  16 |  None  |
# | 7  |  Kimura  |   3   |  11 |  None  |
# | 8  |   Sato   |   1   |  14 |  None  |
# +----+----------+-------+-----+--------+

# %%
# %%sql
# ROLLBACK
# Out:
# Running query in 'duckdb://'
# +---------+
# | Success |
# +---------+
# +---------+

# %%
# %%sql
# SELECT * FROM emp_list;
# Out:
# Running query in 'duckdb://'
# +----+----------+-------+-----+--------+
# | id |   name   | class | age | height |
# +----+----------+-------+-----+--------+
# | 1  |  Yamada  |   1   |  14 |  150   |
# | 2  |  Tanaka  |   2   |  13 |  150   |
# | 3  |  Suzuki  |   1   |  13 |  150   |
# | 4  |   Kato   |   2   |  15 |  150   |
# | 5  |   Ito    |   3   |  12 |  None  |
# | 6  | Takeuchi |   2   |  16 |  None  |
# | 7  |  Kimura  |   3   |  11 |  None  |
# | 8  |   Sato   |   1   |  14 |  None  |
# +----+----------+-------+-----+--------+

# %%
# %%sql
# UPDATE emp_list SET height = 155 WHERE id IN (5,6);
# Out:
# Running query in 'duckdb://'
# +-------+
# | Count |
# +-------+
# +-------+

# %%
# %%sql
# UPDATE emp_list SET height = 160 WHERE id IN (7,8);
# Out:
# Running query in 'duckdb://'
# +-------+
# | Count |
# +-------+
# +-------+

# %%
# %%sql
# SELECT * FROM emp_list;
# Out:
# Running query in 'duckdb://'
# +----+----------+-------+-----+--------+
# | id |   name   | class | age | height |
# +----+----------+-------+-----+--------+
# | 1  |  Yamada  |   1   |  14 |  150   |
# | 2  |  Tanaka  |   2   |  13 |  150   |
# | 3  |  Suzuki  |   1   |  13 |  150   |
# | 4  |   Kato   |   2   |  15 |  150   |
# | 5  |   Ito    |   3   |  12 |  155   |
# | 6  | Takeuchi |   2   |  16 |  155   |
# | 7  |  Kimura  |   3   |  11 |  160   |
# | 8  |   Sato   |   1   |  14 |  160   |
# +----+----------+-------+-----+--------+

# %%
# %%sql
# SELECT COUNT(*) FROM emp_list;
# Out:
# Running query in 'duckdb://'
# +--------------+
# | count_star() |
# +--------------+
# |      8       |
# +--------------+

# %%
# %%sql
# SELECT COUNT(*) AS cnt FROM emp_list;
# Out:
# Running query in 'duckdb://'
# +-----+
# | cnt |
# +-----+
# |  8  |
# +-----+

# %%
# %%sql
# SELECT COUNT(DISTINCT class) AS classCnt FROM emp_list;
# Out:
# Running query in 'duckdb://'
# +----------+
# | classCnt |
# +----------+
# |    3     |
# +----------+

# %%
# %%sql
# SELECT AVG(age) AS avgAge FROM emp_list;
# Out:
# Running query in 'duckdb://'
# +--------+
# | avgAge |
# +--------+
# |  13.5  |
# +--------+

# %%
# %%sql
# SELECT CAST(SUM(age) AS REAL) / CAST(COUNT(*) AS REAL) AS avgAge FROM emp_list;
# Out:
# Running query in 'duckdb://'
# +--------+
# | avgAge |
# +--------+
# |  13.5  |
# +--------+

# %%
# %%sql
# SELECT MIN(age) AS minAge, MAX(age) AS maxAge FROM emp_list;
# Out:
# Running query in 'duckdb://'
# +--------+--------+
# | minAge | maxAge |
# +--------+--------+
# |   11   |   16   |
# +--------+--------+

# %% [markdown]
# To sort a table, we use `ORDER BY`.
#
# ```sql
# SELECT column1, ... FROM table_name
# ORDER BY columnN; -- default is in ascending order
# ```
#
# To sort in descending order, we add `DESC` argument at the end.
#
# ```sql
# SELECT column1, ... FROM table_name
# ORDER BY columnN DESC; -- in descending order
# ```
#
# Note that for strings, `ORDER BY` will sort in alphabetical order.

# %%
# %%sql
# SELECT * FROM emp_list ORDER BY id DESC;
# Out:
# Running query in 'duckdb://'
# +----+----------+-------+-----+--------+
# | id |   name   | class | age | height |
# +----+----------+-------+-----+--------+
# | 8  |   Sato   |   1   |  14 |  160   |
# | 7  |  Kimura  |   3   |  11 |  160   |
# | 6  | Takeuchi |   2   |  16 |  155   |
# | 5  |   Ito    |   3   |  12 |  155   |
# | 4  |   Kato   |   2   |  15 |  150   |
# | 3  |  Suzuki  |   1   |  13 |  150   |
# | 2  |  Tanaka  |   2   |  13 |  150   |
# | 1  |  Yamada  |   1   |  14 |  150   |
# +----+----------+-------+-----+--------+

# %%
# %%sql
# SELECT * FROM emp_list ORDER BY age;
# Out:
# Running query in 'duckdb://'
# +----+----------+-------+-----+--------+
# | id |   name   | class | age | height |
# +----+----------+-------+-----+--------+
# | 7  |  Kimura  |   3   |  11 |  160   |
# | 5  |   Ito    |   3   |  12 |  155   |
# | 2  |  Tanaka  |   2   |  13 |  150   |
# | 3  |  Suzuki  |   1   |  13 |  150   |
# | 1  |  Yamada  |   1   |  14 |  150   |
# | 8  |   Sato   |   1   |  14 |  160   |
# | 4  |   Kato   |   2   |  15 |  150   |
# | 6  | Takeuchi |   2   |  16 |  155   |
# +----+----------+-------+-----+--------+

# %% [markdown]
# The column listed first has priority (in this case, `class`)

# %%
# %%sql
# SELECT * FROM emp_list ORDER BY class, age;
# Out:
# Running query in 'duckdb://'
# +----+----------+-------+-----+--------+
# | id |   name   | class | age | height |
# +----+----------+-------+-----+--------+
# | 3  |  Suzuki  |   1   |  13 |  150   |
# | 1  |  Yamada  |   1   |  14 |  150   |
# | 8  |   Sato   |   1   |  14 |  160   |
# | 2  |  Tanaka  |   2   |  13 |  150   |
# | 4  |   Kato   |   2   |  15 |  150   |
# | 6  | Takeuchi |   2   |  16 |  155   |
# | 7  |  Kimura  |   3   |  11 |  160   |
# | 5  |   Ito    |   3   |  12 |  155   |
# +----+----------+-------+-----+--------+

# %%
# %%sql
# SELECT * FROM emp_list LIMIT 3;
# # Limit - no. of rows returned
# Out:
# Running query in 'duckdb://'
# +----+--------+-------+-----+--------+
# | id |  name  | class | age | height |
# +----+--------+-------+-----+--------+
# | 1  | Yamada |   1   |  14 |  150   |
# | 2  | Tanaka |   2   |  13 |  150   |
# | 3  | Suzuki |   1   |  13 |  150   |
# +----+--------+-------+-----+--------+

# %%
# %%sql
# SELECT * FROM emp_list WHERE class = 2 AND age >=15;
# Out:
# Running query in 'duckdb://'
# +----+----------+-------+-----+--------+
# | id |   name   | class | age | height |
# +----+----------+-------+-----+--------+
# | 4  |   Kato   |   2   |  15 |  150   |
# | 6  | Takeuchi |   2   |  16 |  155   |
# +----+----------+-------+-----+--------+

# %%
# %%sql
# SELECT * FROM emp_list WHERE class = 1 OR age >=15;
# Out:
# Running query in 'duckdb://'
# +----+----------+-------+-----+--------+
# | id |   name   | class | age | height |
# +----+----------+-------+-----+--------+
# | 1  |  Yamada  |   1   |  14 |  150   |
# | 3  |  Suzuki  |   1   |  13 |  150   |
# | 4  |   Kato   |   2   |  15 |  150   |
# | 6  | Takeuchi |   2   |  16 |  155   |
# | 8  |   Sato   |   1   |  14 |  160   |
# +----+----------+-------+-----+--------+

# %%
# %%sql
# SELECT COUNT(DISTINCT age) as ageCnt FROM emp_list;
# Out:
# Running query in 'duckdb://'
# +--------+
# | ageCnt |
# +--------+
# |   6    |
# +--------+

# %%
# %%sql
# SELECT Min(height) as minHeight , Max(height) as maxheight FROM emp_list;
# Out:
# Running query in 'duckdb://'
# +-----------+-----------+
# | minHeight | maxheight |
# +-----------+-----------+
# |    150    |    160    |
# +-----------+-----------+

# %%
# %%sql
# SELECT * FROM emp_list WHERE height >= 155 AND class = 3;
# Out:
# Running query in 'duckdb://'
# +----+--------+-------+-----+--------+
# | id |  name  | class | age | height |
# +----+--------+-------+-----+--------+
# | 5  |  Ito   |   3   |  12 |  155   |
# | 7  | Kimura |   3   |  11 |  160   |
# +----+--------+-------+-----+--------+

# %% [markdown]
# Using SQL to aggregate data by group is similar to the pivot table feature in Excel. In SQL, we use `GROUP BY` statement.
#
# ```sql
# SELECT column1, ...
# FROM table_name
# GROUP BY column_name(s)
# ```
#
# `GROUP BY` is often used with aggregation functions such as `COUNT()`, `AVG()`, `MAX()`, `MIN()`, etc.

# %%
# %%sql
# SELECT class, COUNT(*) AS num FROM emp_list GROUP BY class;
# Out:
# Running query in 'duckdb://'
# +-------+-----+
# | class | num |
# +-------+-----+
# |   1   |  3  |
# |   2   |  3  |
# |   3   |  2  |
# +-------+-----+

# %%
# %%sql
# SELECT class, COUNT(*) AS num, AVG(age) AS avgAge FROM emp_list GROUP BY class;
# Out:
# Running query in 'duckdb://'
# +-------+-----+--------------------+
# | class | num |       avgAge       |
# +-------+-----+--------------------+
# |   1   |  3  | 13.666666666666666 |
# |   2   |  3  | 14.666666666666666 |
# |   3   |  2  |        11.5        |
# +-------+-----+--------------------+

# %% [markdown]
# To filter **after** grouping, you use `HAVING`.
#
# To filter **before** grouping, you use `WHERE`

# %%
# %%sql
# SELECT class, AVG(age) AS avgAge FROM emp_list GROUP BY class HAVING avgAge>13;
# Out:
# Running query in 'duckdb://'
# +-------+--------------------+
# | class |       avgAge       |
# +-------+--------------------+
# |   1   | 13.666666666666666 |
# |   2   | 14.666666666666666 |
# +-------+--------------------+

# %%
# %%sql
# SELECT class, AVG(age) AS avgAge FROM emp_list WHERE age >13 GROUP BY class;
# Out:
# Running query in 'duckdb://'
# +-------+--------+
# | class | avgAge |
# +-------+--------+
# |   1   |  14.0  |
# |   2   |  15.5  |
# +-------+--------+

# %%
# %%sql
# SELECT class, age, COUNT(*) AS num FROM emp_list GROUP BY class, age;
# Out:
# Running query in 'duckdb://'
# +-------+-----+-----+
# | class | age | num |
# +-------+-----+-----+
# |   1   |  13 |  1  |
# |   1   |  14 |  2  |
# |   2   |  13 |  1  |
# |   2   |  15 |  1  |
# |   2   |  16 |  1  |
# |   3   |  11 |  1  |
# |   3   |  12 |  1  |
# +-------+-----+-----+

# %%
# %%sql
# SELECT class, age, COUNT(*) AS num FROM emp_list GROUP BY 1,2;
# # specifying columns to group by by their column numbers - confusing for larger databases
# Out:
# Running query in 'duckdb://'
# +-------+-----+-----+
# | class | age | num |
# +-------+-----+-----+
# |   1   |  13 |  1  |
# |   1   |  14 |  2  |
# |   2   |  13 |  1  |
# |   2   |  15 |  1  |
# |   2   |  16 |  1  |
# |   3   |  11 |  1  |
# |   3   |  12 |  1  |
# +-------+-----+-----+

# %% [markdown]
# >The order of the querying clauses:
# >
# >**SELECT ... FROM ... WHERE ... GROUP BY ... HAVING ... ORDER BY ...**
# >
# >Mnemonic:
# >**S**o **F**ew **W**orkers **G**o **H**ome **O**n time.

# %%
# %%sql
# SELECT class, AVG(height) AS avgHeight FROM emp_list GROUP BY class;
# Out:
# Running query in 'duckdb://'
# +-------+--------------------+
# | class |     avgHeight      |
# +-------+--------------------+
# |   1   | 153.33333333333334 |
# |   2   | 151.66666666666666 |
# |   3   |       157.5        |
# +-------+--------------------+

# %%
# %%sql
# SELECT class, COUNT(*) AS cnt, MIN(height) AS minHeight, MAX(height) AS maxHeight FROM emp_list GROUP BY class;
# # order in which columns are mentioned after SELECT is the order in which they appear in output
# Out:
# Running query in 'duckdb://'
# +-------+-----+-----------+-----------+
# | class | cnt | minHeight | maxHeight |
# +-------+-----+-----------+-----------+
# |   1   |  3  |    150    |    160    |
# |   2   |  3  |    150    |    155    |
# |   3   |  2  |    155    |    160    |
# +-------+-----+-----------+-----------+

# %%
# %%sql
# SELECT class, COUNT(*) AS cnt, MIN(height) AS minHeight, MAX(height) AS maxHeight FROM emp_list WHERE age>13 GROUP BY class;
# # after SELECT mention only those columns which you need in output, for ex. here no need to mention age
# Out:
# Running query in 'duckdb://'
# +-------+-----+-----------+-----------+
# | class | cnt | minHeight | maxHeight |
# +-------+-----+-----------+-----------+
# |   1   |  2  |    150    |    160    |
# |   2   |  2  |    150    |    155    |
# +-------+-----+-----------+-----------+

# %%
# %%sql
# DROP TABLE IF EXISTS emp_list2;
# Out:
# Running query in 'duckdb://'
# +---------+
# | Success |
# +---------+
# +---------+

# %% [markdown]
# To copy an existing table, we combine `COMBINE TABLE` with `AS`.
#
# ```sql
# CREATE TABLE new_table_name AS
#     SELECT column1, ...
#     FROM table_name
#     WHERE condition;
# ```
#
# The records will also be copied from the existing table. To delete all records, we can use a condition that does not match with any record in the existing table.
#
# For example, `class`=100000 does not exist, so there will be zero records.

# %%
# %%sql
# CREATE TABLE emp_list2 AS SELECT * FROM emp_list WHERE class = 100000;
# Out:
# Running query in 'duckdb://'
# +-------+
# | Count |
# +-------+
# +-------+

# %%
# %%sql
# SELECT * FROM emp_list2;
# Out:
# Running query in 'duckdb://'
# +----+------+-------+-----+--------+
# | id | name | class | age | height |
# +----+------+-------+-----+--------+
# +----+------+-------+-----+--------+

# %%
# %%sql
# INSERT INTO emp_list2 (id, name, class, age, height)
# VALUES (1,'Yamada',1,14,150),
#        (9,'Nagata',4,11,160),
#        (10,'Sugino',2,13,150),
#        (11,'Takayama',1,14,155),
#        (12,'John',3,16,165);
# Out:
# Running query in 'duckdb://'
# +-------+
# | Count |
# +-------+
# +-------+

# %%
# %%sql
# SELECT * FROM emp_list2;
# Out:
# Running query in 'duckdb://'
# +----+----------+-------+-----+--------+
# | id |   name   | class | age | height |
# +----+----------+-------+-----+--------+
# | 1  |  Yamada  |   1   |  14 |  150   |
# | 9  |  Nagata  |   4   |  11 |  160   |
# | 10 |  Sugino  |   2   |  13 |  150   |
# | 11 | Takayama |   1   |  14 |  155   |
# | 12 |   John   |   3   |  16 |  165   |
# +----+----------+-------+-----+--------+

# %% [markdown]
# To concatenate multiple results of `SELECT` statements, we can use `UNION`.
#
# ```sql
# SELECT column_name(s) FROM table1
# UNION -- excludes duplicates
# SELECT column_name(s) FROM table2
# ```
#
# ```sql
# SELECT column_name(s) FROM table1
# UNION ALL -- allows duplicates
# SELECT column_name(s) FROM table2
# ```

# %%
# %%sql
# SELECT * FROM emp_list
# UNION
# SELECT * FROM emp_list2;
# Out:
# Running query in 'duckdb://'
# +----+----------+-------+-----+--------+
# | id |   name   | class | age | height |
# +----+----------+-------+-----+--------+
# | 2  |  Tanaka  |   2   |  13 |  150   |
# | 7  |  Kimura  |   3   |  11 |  160   |
# | 12 |   John   |   3   |  16 |  165   |
# | 5  |   Ito    |   3   |  12 |  155   |
# | 6  | Takeuchi |   2   |  16 |  155   |
# | 8  |   Sato   |   1   |  14 |  160   |
# | 11 | Takayama |   1   |  14 |  155   |
# | 10 |  Sugino  |   2   |  13 |  150   |
# | 4  |   Kato   |   2   |  15 |  150   |
# | 1  |  Yamada  |   1   |  14 |  150   |
# +----+----------+-------+-----+--------+
# Truncated to displaylimit of 10.

# %%
# %%sql
# SELECT * FROM emp_list UNION ALL SELECT * FROM emp_list2;
# # we see two duplicates for id=1
# Out:
# Running query in 'duckdb://'
# +----+----------+-------+-----+--------+
# | id |   name   | class | age | height |
# +----+----------+-------+-----+--------+
# | 1  |  Yamada  |   1   |  14 |  150   |
# | 2  |  Tanaka  |   2   |  13 |  150   |
# | 3  |  Suzuki  |   1   |  13 |  150   |
# | 4  |   Kato   |   2   |  15 |  150   |
# | 5  |   Ito    |   3   |  12 |  155   |
# | 6  | Takeuchi |   2   |  16 |  155   |
# | 7  |  Kimura  |   3   |  11 |  160   |
# | 8  |   Sato   |   1   |  14 |  160   |
# | 1  |  Yamada  |   1   |  14 |  150   |
# | 9  |  Nagata  |   4   |  11 |  160   |
# +----+----------+-------+-----+--------+
# Truncated to displaylimit of 10.

# %%
# %%sql
# CREATE TABLE score(
#     id INT PRIMARY KEY,
#     math INT,
#     english INT,
#     science INT
# );
# Out:
# Running query in 'duckdb://'
# +-------+
# | Count |
# +-------+
# +-------+

# %%
# %%sql
# INSERT INTO score (id, math, english, science)
# VALUES (1,10,10,40),(2,NULL,60,100),(3,30,40,60),
#        (5,25,31,10),(6,50,30,10),(8,90,100,90),
#        (9,67,71,50),(11,100,40,88),(15,76,21,13);
# Out:
# Running query in 'duckdb://'
# +-------+
# | Count |
# +-------+
# +-------+

# %%
# %%sql
# SELECT * FROM score;
# Out:
# Running query in 'duckdb://'
# +----+------+---------+---------+
# | id | math | english | science |
# +----+------+---------+---------+
# | 1  |  10  |    10   |    40   |
# | 2  | None |    60   |   100   |
# | 3  |  30  |    40   |    60   |
# | 5  |  25  |    31   |    10   |
# | 6  |  50  |    30   |    10   |
# | 8  |  90  |   100   |    90   |
# | 9  |  67  |    71   |    50   |
# | 11 | 100  |    40   |    88   |
# | 15 |  76  |    21   |    13   |
# +----+------+---------+---------+

# %% [markdown]
# The syntax of joining is as follows:
#
# ```sql
# SELECT column_name(s)
# FROM table1
# JOIN table2 -- join type you want to use
# ON table1.column_name = table2.column_name;
# ```
#
# You can also assign simple aliases to the table names.
#
# ```sql
# SELECT column_name(s)
# FROM table1 t1 -- assign table1 as t1
# JOIN table2 t2 -- assign table2 as t2
# ON t1.column_name = t2.column_name; -- using aliases
# ```

# %%
# %%sql
# SELECT *
# FROM emp_list a
# JOIN score b   --inner join
# ON a.id = b.id;
# Out:
# Running query in 'duckdb://'
# +----+----------+-------+-----+--------+------+------+---------+---------+
# | id |   name   | class | age | height | id_1 | math | english | science |
# +----+----------+-------+-----+--------+------+------+---------+---------+
# | 1  |  Yamada  |   1   |  14 |  150   |  1   |  10  |    10   |    40   |
# | 2  |  Tanaka  |   2   |  13 |  150   |  2   | None |    60   |   100   |
# | 3  |  Suzuki  |   1   |  13 |  150   |  3   |  30  |    40   |    60   |
# | 5  |   Ito    |   3   |  12 |  155   |  5   |  25  |    31   |    10   |
# | 6  | Takeuchi |   2   |  16 |  155   |  6   |  50  |    30   |    10   |
# | 8  |   Sato   |   1   |  14 |  160   |  8   |  90  |   100   |    90   |
# +----+----------+-------+-----+--------+------+------+---------+---------+

# %%
# %%sql
# SELECT *
# FROM emp_list a
# LEFT JOIN score b
# ON a.id = b.id;
# # table on left is the base, if no matching data exists on the right, it becomes None(null)
# Out:
# Running query in 'duckdb://'
# +----+----------+-------+-----+--------+------+------+---------+---------+
# | id |   name   | class | age | height | id_1 | math | english | science |
# +----+----------+-------+-----+--------+------+------+---------+---------+
# | 1  |  Yamada  |   1   |  14 |  150   |  1   |  10  |    10   |    40   |
# | 2  |  Tanaka  |   2   |  13 |  150   |  2   | None |    60   |   100   |
# | 3  |  Suzuki  |   1   |  13 |  150   |  3   |  30  |    40   |    60   |
# | 5  |   Ito    |   3   |  12 |  155   |  5   |  25  |    31   |    10   |
# | 6  | Takeuchi |   2   |  16 |  155   |  6   |  50  |    30   |    10   |
# | 8  |   Sato   |   1   |  14 |  160   |  8   |  90  |   100   |    90   |
# | 4  |   Kato   |   2   |  15 |  150   | None | None |   None  |   None  |
# | 7  |  Kimura  |   3   |  11 |  160   | None | None |   None  |   None  |
# +----+----------+-------+-----+--------+------+------+---------+---------+

# %%
# %%sql
# SELECT * FROM emp_list a JOIN emp_list b ON a.id=b.id;
# # Self join
# Out:
# Running query in 'duckdb://'
# +----+----------+-------+-----+--------+------+----------+---------+-------+----------+
# | id |   name   | class | age | height | id_1 |  name_1  | class_1 | age_1 | height_1 |
# +----+----------+-------+-----+--------+------+----------+---------+-------+----------+
# | 1  |  Yamada  |   1   |  14 |  150   |  1   |  Yamada  |    1    |   14  |   150    |
# | 2  |  Tanaka  |   2   |  13 |  150   |  2   |  Tanaka  |    2    |   13  |   150    |
# | 3  |  Suzuki  |   1   |  13 |  150   |  3   |  Suzuki  |    1    |   13  |   150    |
# | 4  |   Kato   |   2   |  15 |  150   |  4   |   Kato   |    2    |   15  |   150    |
# | 5  |   Ito    |   3   |  12 |  155   |  5   |   Ito    |    3    |   12  |   155    |
# | 6  | Takeuchi |   2   |  16 |  155   |  6   | Takeuchi |    2    |   16  |   155    |
# | 7  |  Kimura  |   3   |  11 |  160   |  7   |  Kimura  |    3    |   11  |   160    |
# | 8  |   Sato   |   1   |  14 |  160   |  8   |   Sato   |    1    |   14  |   160    |
# +----+----------+-------+-----+--------+------+----------+---------+-------+----------+

# %%
# %%sql
# CREATE TABLE cardtb(
#     id INT PRIMARY KEY, point INT, money INT
# );
# Out:
# Running query in 'duckdb://'
# +-------+
# | Count |
# +-------+
# +-------+

# %%
# %%sql
# INSERT INTO cardtb (id, point, money)
# VALUES (1, 100, 1000), (3, 50, 500), (4, 30, 600), (5, 10, 10), (7, 100, 1000), (8, 2000, 100);
# Out:
# Running query in 'duckdb://'
# +-------+
# | Count |
# +-------+
# +-------+

# %%
# %%sql
# SELECT * FROM cardtb;
# Out:
# Running query in 'duckdb://'
# +----+-------+-------+
# | id | point | money |
# +----+-------+-------+
# | 1  |  100  |  1000 |
# | 3  |   50  |  500  |
# | 4  |   30  |  600  |
# | 5  |   10  |   10  |
# | 7  |  100  |  1000 |
# | 8  |  2000 |  100  |
# +----+-------+-------+

# %%
# %%sql
# SELECT * FROM emp_list a JOIN cardtb b ON a.id = b.id;
# Out:
# Running query in 'duckdb://'
# +----+--------+-------+-----+--------+------+-------+-------+
# | id |  name  | class | age | height | id_1 | point | money |
# +----+--------+-------+-----+--------+------+-------+-------+
# | 1  | Yamada |   1   |  14 |  150   |  1   |  100  |  1000 |
# | 3  | Suzuki |   1   |  13 |  150   |  3   |   50  |  500  |
# | 4  |  Kato  |   2   |  15 |  150   |  4   |   30  |  600  |
# | 5  |  Ito   |   3   |  12 |  155   |  5   |   10  |   10  |
# | 7  | Kimura |   3   |  11 |  160   |  7   |  100  |  1000 |
# | 8  |  Sato  |   1   |  14 |  160   |  8   |  2000 |  100  |
# +----+--------+-------+-----+--------+------+-------+-------+

# %%
# %%sql
# SELECT * FROM emp_list a LEFT JOIN cardtb b ON a.id = b.id;
# Out:
# Running query in 'duckdb://'
# +----+----------+-------+-----+--------+------+-------+-------+
# | id |   name   | class | age | height | id_1 | point | money |
# +----+----------+-------+-----+--------+------+-------+-------+
# | 1  |  Yamada  |   1   |  14 |  150   |  1   |  100  |  1000 |
# | 3  |  Suzuki  |   1   |  13 |  150   |  3   |   50  |  500  |
# | 4  |   Kato   |   2   |  15 |  150   |  4   |   30  |  600  |
# | 5  |   Ito    |   3   |  12 |  155   |  5   |   10  |   10  |
# | 7  |  Kimura  |   3   |  11 |  160   |  7   |  100  |  1000 |
# | 8  |   Sato   |   1   |  14 |  160   |  8   |  2000 |  100  |
# | 2  |  Tanaka  |   2   |  13 |  150   | None |  None |  None |
# | 6  | Takeuchi |   2   |  16 |  155   | None |  None |  None |
# +----+----------+-------+-----+--------+------+-------+-------+

# %% [markdown]
# When working with data, there are times when you might want to split it into categories and aggregate each one. SQL allows for conditional logic using `CASE` expression. The syntax is as follows:
#
# ```sql
# CASE
#     WHEN condition1 THEN result1
#     WHEN condition2 THEN result2
#     ...
#     ELSE result
# END;
# ```

# %%
# %%sql
# SELECT id, name,
# CASE
#     WHEN class = 1 THEN 'A'
#     WHEN class = 2 THEN 'B'
#     WHEN class = 3 THEn 'C'
#     ELSE 'others'
# END
# AS className FROM emp_list;
# Out:
# Running query in 'duckdb://'
# +----+----------+-----------+
# | id |   name   | className |
# +----+----------+-----------+
# | 1  |  Yamada  |     A     |
# | 2  |  Tanaka  |     B     |
# | 3  |  Suzuki  |     A     |
# | 4  |   Kato   |     B     |
# | 5  |   Ito    |     C     |
# | 6  | Takeuchi |     B     |
# | 7  |  Kimura  |     C     |
# | 8  |   Sato   |     A     |
# +----+----------+-----------+

# %% [markdown]
# Subquery is a query inside a query, in a nested structure. Subqueries allow you to treat information extracted from the original table as a separate table.
#
# In this example, we treat the contents of the `emp_list` table as a table named `b` using a subquery.

# %%
# %%sql
# SELECT b.name, b.age FROM
#   (SELECT a.age, a.name FROM emp_list a WHERE a.class = 1) b;
# Out:
# Running query in 'duckdb://'
# +--------+-----+
# |  name  | age |
# +--------+-----+
# | Yamada |  14 |
# | Suzuki |  13 |
# |  Sato  |  14 |
# +--------+-----+

# %%
# %%sql
# SELECT b.* FROM (SELECT a.* FROM emp_list a WHERE a.class = 1) b;
# Out:
# Running query in 'duckdb://'
# +----+--------+-------+-----+--------+
# | id |  name  | class | age | height |
# +----+--------+-------+-----+--------+
# | 1  | Yamada |   1   |  14 |  150   |
# | 3  | Suzuki |   1   |  13 |  150   |
# | 8  |  Sato  |   1   |  14 |  160   |
# +----+--------+-------+-----+--------+

# %%
# %%sql
# SELECT id, name,
# CASE
#     WHEN height <155 THEN 'below_155'
#     WHEN height =155 THEN 'equal_155'
#     WHEN height >155 THEN 'over_155'
# ELSE 'others'
# END AS heightLevel FROM emp_list;
# Out:
# Running query in 'duckdb://'
# +----+----------+-------------+
# | id |   name   | heightLevel |
# +----+----------+-------------+
# | 1  |  Yamada  |  below_155  |
# | 2  |  Tanaka  |  below_155  |
# | 3  |  Suzuki  |  below_155  |
# | 4  |   Kato   |  below_155  |
# | 5  |   Ito    |  equal_155  |
# | 6  | Takeuchi |  equal_155  |
# | 7  |  Kimura  |   over_155  |
# | 8  |   Sato   |   over_155  |
# +----+----------+-------------+

# %%
# %%sql
# SELECT * FROM emp_list;
# # the column heightLevel is not added to table since we didn't alter tbale, it's just displayed
# Out:
# Running query in 'duckdb://'
# +----+----------+-------+-----+--------+
# | id |   name   | class | age | height |
# +----+----------+-------+-----+--------+
# | 1  |  Yamada  |   1   |  14 |  150   |
# | 2  |  Tanaka  |   2   |  13 |  150   |
# | 3  |  Suzuki  |   1   |  13 |  150   |
# | 4  |   Kato   |   2   |  15 |  150   |
# | 5  |   Ito    |   3   |  12 |  155   |
# | 6  | Takeuchi |   2   |  16 |  155   |
# | 7  |  Kimura  |   3   |  11 |  160   |
# | 8  |   Sato   |   1   |  14 |  160   |
# +----+----------+-------+-----+--------+

# %%
# %%sql
# SELECT b.heightLevel, COUNT(*) AS cnt
# FROM (SELECT id, name,
# CASE
#     WHEN height <155 THEN 'below_155'
#     WHEN height = 155 THEN 'equal_155'
#     WHEN height > 155 THEN 'over_155'
#     ELSE 'others'
# END AS heightLevel FROM emp_list) b GROUP BY heightLevel;
# Out:
# Running query in 'duckdb://'
# +-------------+-----+
# | heightLevel | cnt |
# +-------------+-----+
# |   over_155  |  2  |
# |  equal_155  |  2  |
# |  below_155  |  4  |
# +-------------+-----+

# %%
# %%sql
# SELECT b.heightLevel, AVG(age) as avgAge
# FROM(
#     SELECT id, name, age,
#     CASE
#         WHEN height <155 THEN 'below_155'
#         WHEN height = 155 THEN 'equal_155'
#         WHEN height > 155 THEN 'over_155'
#         ELSE 'others'
#     END AS heightLevel FROM emp_list
# ) b GROUP BY heightLevel;
# Out:
# Running query in 'duckdb://'
# +-------------+--------+
# | heightLevel | avgAge |
# +-------------+--------+
# |  below_155  | 13.75  |
# |  equal_155  |  14.0  |
# |   over_155  |  12.5  |
# +-------------+--------+

# %% [markdown]
# A **view** is a virtual table that stores your query logic in advance.
# So far, we have been querying data directly from tables to obtain the information we need. However, setting conditions and extracting data from each table every single time can be a bit tedious. We could create a table for every type of data we need, but this requires updating the table every time the source data changes. Using views allows us to always obtain the latest data easily without updating the table.
#
# The method for creating a view is almost the same as for creating a table, except we use `CREATE VIEW`.
#
# ```sql
# CREATE VIEW view_name AS
# SELECT columns1, ...
# FROM table_name;
# ```

# %%
# %%sql
# CREATE VIEW v1 AS
# SELECT id, name
# FROM emp_list;
# Out:
# Running query in 'duckdb://'
# +-------+
# | Count |
# +-------+
# +-------+

# %%
# %%sql
# SELECT * FROM v1;
# Out:
# Running query in 'duckdb://'
# +----+----------+
# | id |   name   |
# +----+----------+
# | 1  |  Yamada  |
# | 2  |  Tanaka  |
# | 3  |  Suzuki  |
# | 4  |   Kato   |
# | 5  |   Ito    |
# | 6  | Takeuchi |
# | 7  |  Kimura  |
# | 8  |   Sato   |
# +----+----------+

# %%
# %%sql
# CREATE VIEW v2 AS
# SELECT id, name,
# CASE
#     WHEN class = 1 THEN 'A'
#     WHEN class = 2 THEN 'B'
#     WHEN class = 3 THEN 'C'
#     ELSE 'others'
# END AS className FROM emp_list;
# Out:
# Running query in 'duckdb://'
# +-------+
# | Count |
# +-------+
# +-------+

# %%
# %%sql
# SELECT * FROM v2;
# Out:
# Running query in 'duckdb://'
# +----+----------+-----------+
# | id |   name   | className |
# +----+----------+-----------+
# | 1  |  Yamada  |     A     |
# | 2  |  Tanaka  |     B     |
# | 3  |  Suzuki  |     A     |
# | 4  |   Kato   |     B     |
# | 5  |   Ito    |     C     |
# | 6  | Takeuchi |     B     |
# | 7  |  Kimura  |     C     |
# | 8  |   Sato   |     A     |
# +----+----------+-----------+

# %% [markdown]
# In DuckDB, you cannot update views (shows error if try to use INSERT INTO for views)
# The following command indicates that it is a view.

# %%
# %%sql
# SELECT name, SQL FROM sqlite_master WHERE type = 'view';
# Out:
# Running query in 'duckdb://'
# +------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | name |                                                                                           sql                                                                                            |
# +------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |  v1  |                                                                    CREATE VIEW v1 AS SELECT id, "name" FROM emp_list;                                                                    |
# |  v2  | CREATE VIEW v2 AS SELECT id, "name", CASE  WHEN (("class" = 1)) THEN ('A') WHEN (("class" = 2)) THEN ('B') WHEN (("class" = 3)) THEN ('C') ELSE 'others' END AS className FROM emp_list; |
# +------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+

# %%
# %%sql
# CREATE VIEW v3 AS
# SELECT id, name FROM emp_list2;
# Out:
# Running query in 'duckdb://'
# +-------+
# | Count |
# +-------+
# +-------+

# %%
# %%sql
# SELECT * FROM v3;
# Out:
# Running query in 'duckdb://'
# +----+----------+
# | id |   name   |
# +----+----------+
# | 1  |  Yamada  |
# | 9  |  Nagata  |
# | 10 |  Sugino  |
# | 11 | Takayama |
# | 12 |   John   |
# +----+----------+

# %%
# %%sql
# CREATE VIEW v4 AS SELECT a.id, a.name FROM emp_list a JOIN score b ON a.id = b.id;
# Out:
# Running query in 'duckdb://'
# +-------+
# | Count |
# +-------+
# +-------+

# %%
# %%sql
# SELECT * FROM v4;
# Out:
# Running query in 'duckdb://'
# +----+----------+
# | id |   name   |
# +----+----------+
# | 1  |  Yamada  |
# | 2  |  Tanaka  |
# | 3  |  Suzuki  |
# | 5  |   Ito    |
# | 6  | Takeuchi |
# | 8  |   Sato   |
# +----+----------+
